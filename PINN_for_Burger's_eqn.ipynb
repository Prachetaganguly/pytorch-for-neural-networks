# %% [markdown]
# <a href="https://colab.research.google.com/github/Prachetaganguly/pytorch-for-neural-networks/blob/main/PINN_for_Burger's_eqn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Burgers' equation is a fundamental PDE used in fluid mechanics, nonlinear wave propagation, and even traffic flow modeling. It’s especially important because it combines nonlinearity + diffusion, making it a simplified model for studying turbulence.
#
# ∂u​/∂t+u∂x/∂u​=ν∂2u/∂x2​
# x:[-1,1]
# t:[0,1]

# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt

#Some plot settings
plt.close('all')
plt.rcParams['font.family']='serif'
plt.rcParams['font.serif']='Times New Roman'
plt.rcParams['font.size']=12
